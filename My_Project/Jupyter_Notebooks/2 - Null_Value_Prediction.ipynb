# %% [markdown]
# # Mult-Dimensional Poverty
# ## Predicting Null Values
# We try to estimate "N/A" or missing values using the sklearns experimental iterative imputer. Make sure you update your sklearn and make the appropriate installations for importing the imputer library.

# %%
# Doing all major library imports
import matplotlib.pyplot as plt
import scikitplot as skplt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import re

from sklearn import datasets, metrics
from sklearn.linear_model import LinearRegression, LogisticRegression,LogisticRegressionCV 
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from matplotlib.colors import ListedColormap
from sklearn.pipeline import Pipeline, make_pipeline

plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import scikitplot as skplt
from matplotlib.colors import ListedColormap
from sklearn.metrics import classification_report, confusion_matrix

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.options.display.float_format = '{:.4f}'.format

# %%
# Importing the merged data
master = pd.read_csv ('../raw_data/poverty_data.csv')
print(master.shape)
master.head()
# Out:
# (5854, 1092)
#
# 1                                          0.7800
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Tourism expenditure (millions of US dollars)  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Tourist/visitor arrivals (thousands)  Trade (% of GDP)  \
# 0                                   nan               nan
# 1                                   nan               nan
# 2                                   nan               nan
# 3                                   nan               nan
# 4                                   nan               nan
#
#    Trade in services (% of GDP)  Trade value of exports  \
# 0                           nan                     nan
# 1                           nan                     nan
# 2                           nan                     nan
# 3                           nan                     nan
# 4                           nan                     nan
#
#    Trademark applications, nonresident, by count  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Trademark applications, resident, by count  \
# 0                                         nan
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
#
#    Transport services (% of commercial service exports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Transport services (% of commercial service imports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Transport services (% of service exports, BoP)  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Transport services (% of service imports, BoP)  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Travel services (% of commercial service exports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of commercial service imports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of service exports, BoP)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Travel services (% of service imports, BoP)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis incidence (per 100,000 people)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis treatment success rate (% of new cases)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Turnover & general taxes on goods & services  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Unallocable social contributions revenue  Unemployment rate  \
# 0                                       nan                nan
# 1                                       nan                nan
# 2                                       nan                nan
# 3                                       nan                nan
# 4                                       nan                nan
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             2.5180
# 2                                             2.6840
# 3                                             2.8900
# 4                                             3.0290
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             3.2050
# 2                                             3.4150
# 3                                             3.7440
# 4                                             3.8970
#
#    Unemployment, total (% of labour force)  \
# 0                                      nan
# 1                                   3.0000
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             2.9760
# 2                                             3.1730
# 3                                             3.4630
# 4                                             3.6120
#
#    Unemployment, youth (% ages 15–24)  \
# 0                                 nan
# 1                              4.7000
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.4390
# 2                                             4.7020
# 3                                             5.1210
# 4                                             5.3510
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.8220
# 2                                             5.0930
# 3                                             5.6130
# 4                                             5.8170
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.7000
# 2                                             4.9690
# 3                                             5.4580
# 4                                             5.6700
#
#    Unit value 95 percent interval - lower bound  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Unit value 95 percent interval - upper bound  Unit value of exports  \
# 0                                           nan                    nan
# 1                                           nan                    nan
# 2                                           nan                    nan
# 3                                           nan                    nan
# 4                                           nan                    nan
#
#    Unmet need for family planning (% of married or in-union women of reproductive age, 15–49 years)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Urban population  Urban population (% of total population)  \
# 0      2628554.0000                                   21.1770
# 1      2828169.0000                                   21.2660
# 2      3093388.0000                                   21.3550
# 3      3391712.0000                                   21.4440
# 4      3677087.0000                                   21.5340
#
#    Urban population (%)  Urban population growth (annual %)  \
# 0               21.2000                              4.8980
# 1                   nan                              7.3196
# 2                   nan                              8.9637
# 3                   nan                              9.2068
# 4                   nan                              8.0786
#
#    Use of IMF credit (DOD, current US$)  Value-added taxes  \
# 0                                   nan                nan
# 1                                   nan                nan
# 2                                   nan                nan
# 3                                   nan                nan
# 4                                   nan                nan
#
#    Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Volume of Imports of goods  Volume of exports of goods  \
# 0                         nan                         nan
# 1                         nan                         nan
# 2                         nan                         nan
# 3                         nan                         nan
# 4                         nan                         nan
#
#    Volume of exports of goods and services  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Volume of imports of goods and services  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Vulnerable employment (% of total employment)  \
# 0                                            nan
# 1                                        90.7000
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            96.7240
# 2                                            96.7970
# 3                                            96.7590
# 4                                            96.6140
#
#    Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            87.7260
# 2                                            88.0240
# 3                                            88.6700
# 4                                            89.1630
#
#    Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            90.7330
# 2                                            90.9420
# 3                                            91.3510
# 4                                            91.6220
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             3.1750
# 2                                             3.1020
# 3                                             3.1370
# 4                                             3.2710
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            11.6300
# 2                                            11.3290
# 3                                            10.6990
# 4                                            10.1920
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             8.8050
# 2                                             8.5920
# 3                                             8.1940
# 4                                             7.9080
#
#    Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Wholesale price index (2010 = 100)  \
# 0                                 nan
# 1                                 nan
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Withdrawals of income from quasi-corporations  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Women with account at financial institution or with mobile money-service provider (% of female population ages 15 and older)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Working poor at PPP$3.20 a day (% of total employment)  \
# 0                                                nan
# 1                                            87.4000
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Young age (0-14) dependency ratio (per 100 people ages 15-64)  \
# 0                                            97.7000
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Youth not in school or employment (% ages 15-24)  \
# 0                                               nan
# 1                                               nan
# 2                                               nan
# 3                                               nan
# 4                                               nan
#
#    Youth unemployment rate (female to male ratio)
# 0                                             nan
# 1                                          0.9200
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
# [5 rows x 1092 columns]

# %%
master = master.drop(['Unnamed: 0'], axis=1)

# %%
master.head()
# Out:
#
# 1                                          0.7800
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Tourism expenditure (millions of US dollars)  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Tourist/visitor arrivals (thousands)  Trade (% of GDP)  \
# 0                                   nan               nan
# 1                                   nan               nan
# 2                                   nan               nan
# 3                                   nan               nan
# 4                                   nan               nan
#
#    Trade in services (% of GDP)  Trade value of exports  \
# 0                           nan                     nan
# 1                           nan                     nan
# 2                           nan                     nan
# 3                           nan                     nan
# 4                           nan                     nan
#
#    Trademark applications, nonresident, by count  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Trademark applications, resident, by count  \
# 0                                         nan
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
#
#    Transport services (% of commercial service exports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Transport services (% of commercial service imports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Transport services (% of service exports, BoP)  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Transport services (% of service imports, BoP)  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Travel services (% of commercial service exports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of commercial service imports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of service exports, BoP)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Travel services (% of service imports, BoP)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis incidence (per 100,000 people)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis treatment success rate (% of new cases)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Turnover & general taxes on goods & services  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Unallocable social contributions revenue  Unemployment rate  \
# 0                                       nan                nan
# 1                                       nan                nan
# 2                                       nan                nan
# 3                                       nan                nan
# 4                                       nan                nan
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             2.5180
# 2                                             2.6840
# 3                                             2.8900
# 4                                             3.0290
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             3.2050
# 2                                             3.4150
# 3                                             3.7440
# 4                                             3.8970
#
#    Unemployment, total (% of labour force)  \
# 0                                      nan
# 1                                   3.0000
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             2.9760
# 2                                             3.1730
# 3                                             3.4630
# 4                                             3.6120
#
#    Unemployment, youth (% ages 15–24)  \
# 0                                 nan
# 1                              4.7000
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.4390
# 2                                             4.7020
# 3                                             5.1210
# 4                                             5.3510
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.8220
# 2                                             5.0930
# 3                                             5.6130
# 4                                             5.8170
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.7000
# 2                                             4.9690
# 3                                             5.4580
# 4                                             5.6700
#
#    Unit value 95 percent interval - lower bound  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Unit value 95 percent interval - upper bound  Unit value of exports  \
# 0                                           nan                    nan
# 1                                           nan                    nan
# 2                                           nan                    nan
# 3                                           nan                    nan
# 4                                           nan                    nan
#
#    Unmet need for family planning (% of married or in-union women of reproductive age, 15–49 years)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Urban population  Urban population (% of total population)  \
# 0      2628554.0000                                   21.1770
# 1      2828169.0000                                   21.2660
# 2      3093388.0000                                   21.3550
# 3      3391712.0000                                   21.4440
# 4      3677087.0000                                   21.5340
#
#    Urban population (%)  Urban population growth (annual %)  \
# 0               21.2000                              4.8980
# 1                   nan                              7.3196
# 2                   nan                              8.9637
# 3                   nan                              9.2068
# 4                   nan                              8.0786
#
#    Use of IMF credit (DOD, current US$)  Value-added taxes  \
# 0                                   nan                nan
# 1                                   nan                nan
# 2                                   nan                nan
# 3                                   nan                nan
# 4                                   nan                nan
#
#    Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Volume of Imports of goods  Volume of exports of goods  \
# 0                         nan                         nan
# 1                         nan                         nan
# 2                         nan                         nan
# 3                         nan                         nan
# 4                         nan                         nan
#
#    Volume of exports of goods and services  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Volume of imports of goods and services  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Vulnerable employment (% of total employment)  \
# 0                                            nan
# 1                                        90.7000
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            96.7240
# 2                                            96.7970
# 3                                            96.7590
# 4                                            96.6140
#
#    Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            87.7260
# 2                                            88.0240
# 3                                            88.6700
# 4                                            89.1630
#
#    Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            90.7330
# 2                                            90.9420
# 3                                            91.3510
# 4                                            91.6220
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             3.1750
# 2                                             3.1020
# 3                                             3.1370
# 4                                             3.2710
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            11.6300
# 2                                            11.3290
# 3                                            10.6990
# 4                                            10.1920
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             8.8050
# 2                                             8.5920
# 3                                             8.1940
# 4                                             7.9080
#
#    Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Wholesale price index (2010 = 100)  \
# 0                                 nan
# 1                                 nan
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Withdrawals of income from quasi-corporations  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Women with account at financial institution or with mobile money-service provider (% of female population ages 15 and older)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Working poor at PPP$3.20 a day (% of total employment)  \
# 0                                                nan
# 1                                            87.4000
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Young age (0-14) dependency ratio (per 100 people ages 15-64)  \
# 0                                            97.7000
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Youth not in school or employment (% ages 15-24)  \
# 0                                               nan
# 1                                               nan
# 2                                               nan
# 3                                               nan
# 4                                               nan
#
#    Youth unemployment rate (female to male ratio)
# 0                                             nan
# 1                                          0.9200
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
# [5 rows x 1091 columns]

# %%
dtypes = pd.DataFrame(master.dtypes, columns=['dtype'])
dtypes.head()
# Out:
#                                                       dtype
# country_code                                         object
# country                                              object
# date                                                  int64
# Access to clean fuels and technologies for cook...  float64
# Adjusted net enrollment rate, primary (% of pri...  float64

# %%
# Converting the predictors to float
print (dtypes[dtypes.dtype == object].shape)
dtypes[dtypes.dtype == object]
# Out:
# (2, 1)
#                dtype
# country_code  object
# country       object

# %%
master.head()
# Out:
#
# 1                                          0.7800
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Tourism expenditure (millions of US dollars)  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Tourist/visitor arrivals (thousands)  Trade (% of GDP)  \
# 0                                   nan               nan
# 1                                   nan               nan
# 2                                   nan               nan
# 3                                   nan               nan
# 4                                   nan               nan
#
#    Trade in services (% of GDP)  Trade value of exports  \
# 0                           nan                     nan
# 1                           nan                     nan
# 2                           nan                     nan
# 3                           nan                     nan
# 4                           nan                     nan
#
#    Trademark applications, nonresident, by count  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Trademark applications, resident, by count  \
# 0                                         nan
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
#
#    Transport services (% of commercial service exports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Transport services (% of commercial service imports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Transport services (% of service exports, BoP)  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Transport services (% of service imports, BoP)  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Travel services (% of commercial service exports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of commercial service imports)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of service exports, BoP)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Travel services (% of service imports, BoP)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis incidence (per 100,000 people)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis treatment success rate (% of new cases)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Turnover & general taxes on goods & services  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Unallocable social contributions revenue  Unemployment rate  \
# 0                                       nan                nan
# 1                                       nan                nan
# 2                                       nan                nan
# 3                                       nan                nan
# 4                                       nan                nan
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             2.5180
# 2                                             2.6840
# 3                                             2.8900
# 4                                             3.0290
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             3.2050
# 2                                             3.4150
# 3                                             3.7440
# 4                                             3.8970
#
#    Unemployment, total (% of labour force)  \
# 0                                      nan
# 1                                   3.0000
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             2.9760
# 2                                             3.1730
# 3                                             3.4630
# 4                                             3.6120
#
#    Unemployment, youth (% ages 15–24)  \
# 0                                 nan
# 1                              4.7000
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.4390
# 2                                             4.7020
# 3                                             5.1210
# 4                                             5.3510
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.8220
# 2                                             5.0930
# 3                                             5.6130
# 4                                             5.8170
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             4.7000
# 2                                             4.9690
# 3                                             5.4580
# 4                                             5.6700
#
#    Unit value 95 percent interval - lower bound  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Unit value 95 percent interval - upper bound  Unit value of exports  \
# 0                                           nan                    nan
# 1                                           nan                    nan
# 2                                           nan                    nan
# 3                                           nan                    nan
# 4                                           nan                    nan
#
#    Unmet need for family planning (% of married or in-union women of reproductive age, 15–49 years)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Urban population  Urban population (% of total population)  \
# 0      2628554.0000                                   21.1770
# 1      2828169.0000                                   21.2660
# 2      3093388.0000                                   21.3550
# 3      3391712.0000                                   21.4440
# 4      3677087.0000                                   21.5340
#
#    Urban population (%)  Urban population growth (annual %)  \
# 0               21.2000                              4.8980
# 1                   nan                              7.3196
# 2                   nan                              8.9637
# 3                   nan                              9.2068
# 4                   nan                              8.0786
#
#    Use of IMF credit (DOD, current US$)  Value-added taxes  \
# 0                                   nan                nan
# 1                                   nan                nan
# 2                                   nan                nan
# 3                                   nan                nan
# 4                                   nan                nan
#
#    Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Volume of Imports of goods  Volume of exports of goods  \
# 0                         nan                         nan
# 1                         nan                         nan
# 2                         nan                         nan
# 3                         nan                         nan
# 4                         nan                         nan
#
#    Volume of exports of goods and services  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Volume of imports of goods and services  \
# 0                                      nan
# 1                                      nan
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Vulnerable employment (% of total employment)  \
# 0                                            nan
# 1                                        90.7000
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            96.7240
# 2                                            96.7970
# 3                                            96.7590
# 4                                            96.6140
#
#    Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            87.7260
# 2                                            88.0240
# 3                                            88.6700
# 4                                            89.1630
#
#    Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            90.7330
# 2                                            90.9420
# 3                                            91.3510
# 4                                            91.6220
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             3.1750
# 2                                             3.1020
# 3                                             3.1370
# 4                                             3.2710
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            11.6300
# 2                                            11.3290
# 3                                            10.6990
# 4                                            10.1920
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                             8.8050
# 2                                             8.5920
# 3                                             8.1940
# 4                                             7.9080
#
#    Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Wholesale price index (2010 = 100)  \
# 0                                 nan
# 1                                 nan
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Withdrawals of income from quasi-corporations  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Women with account at financial institution or with mobile money-service provider (% of female population ages 15 and older)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Working poor at PPP$3.20 a day (% of total employment)  \
# 0                                                nan
# 1                                            87.4000
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Young age (0-14) dependency ratio (per 100 people ages 15-64)  \
# 0                                            97.7000
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Youth not in school or employment (% ages 15-24)  \
# 0                                               nan
# 1                                               nan
# 2                                               nan
# 3                                               nan
# 4                                               nan
#
#    Youth unemployment rate (female to male ratio)
# 0                                             nan
# 1                                          0.9200
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
# [5 rows x 1091 columns]

# %%
# Initiating Iterative Imputer

from sklearn.experimental import enable_iterative_imputer 

from sklearn.impute import IterativeImputer, SimpleImputer

# %%
#Isolating countries that do not have enogh values
vals_per_country = pd.DataFrame(master.groupby('country_code').count().sum(axis=1))
vals_per_country.sort_values(by=0)
# Out:
#                   0
# country_code
# PRK             730
# MCO            2033
# LIE            2841
# NRU            3030
# SMR            3432
# AND            4011
# TUV            5216
# MHL            6935
# PLW            7097
# SSD            7194
# SOM            7372
# FSM            7829
# KNA           10341
# KIR           10380
# DMA           11221
# TKM           11568
# ATG           11822
# MNE           12070
# TLS           12136
# LBY           12414
# GNQ           12478
# ERI           12885
# AFG           12917
# GRD           13234
# DJI           13252
# IRQ           13262
# WSM           13337
# STP           13409
# LBR           13527
# SLB           13812
# PSE           13879
# ARE           13995
# SUR           14123
# CUB           14251
# TON           14292
# SYR           14336
# QAT           14589
# SYC           14698
# YEM           14735
# CAF           14800
# VUT           14834
# MDV           14968
# COM           15016
# GNB           15078
# VCT           15326
# TCD           15436
# HKG           15486
# UZB           15488
# BRN           15600
# BRB           15659
# PNG           15706
# FJI           15719
# HTI           15773
# GUY           15888
# BIH           15914
# MMR           15925
# TTO           15932
# LCA           16059
# GMB           16336
# BHS           16365
# KWT           16411
# COD           16414
# SAU           16496
# TJK           16541
# BTN           16543
# BHR           16699
# ZWE           16738
# SLE           16805
# AGO           16940
# MRT           16949
# CPV           16962
# LAO           16969
# SRB           17073
# GIN           17074
# GAB           17116
# OMN           17273
# RWA           17335
# NAM           17396
# CIV           17430
# NER           17567
# SWZ           17648
# ZMB           17758
# LUX           17798
# ETH           17801
# MWI           17839
# SGP           17871
# VEN           17942
# BDI           17968
# LBN           18063
# CAN           18097
# BFA           18105
# GEO           18135
# MLT           18141
# VNM           18147
# LSO           18210
# LTU           18219
# KHM           18247
# LVA           18267
# COG           18267
# ISL           18346
# GHA           18375
# ARM           18395
# MLI           18442
# BLZ           18466
# MOZ           18477
# NGA           18544
# DZA           18549
# NZL           18574
# AZE           18608
# EST           18612
# HRV           18642
# PAN           18687
# BEN           18728
# IRL           18732
# SVK           18757
# UGA           18770
# BEL           18830
# JPN           18886
# CZE           18891
# NPL           18987
# SVN           19003
# TGO           19043
# MNG           19071
# JAM           19142
# KAZ           19149
# NIC           19196
# POL           19208
# MDG           19245
# BWA           19257
# TZA           19309
# CHN           19337
# CMR           19354
# CYP           19378
# MDA           19389
# IRN           19497
# URY           19497
# KGZ           19501
# AUT           19537
# ISR           19588
# ALB           19605
# PRT           19616
# KOR           19642
# SEN           19665
# RUS           19702
# GRC           19712
# BLR           19721
# CHL           19728
# AUS           19736
# HND           19803
# DEU           19827
# BGD           19837
# DNK           19872
# UKR           19884
# ECU           19900
# MYS           19942
# KEN           19947
# FRA           20024
# NOR           20086
# ITA           20144
# ESP           20148
# PRY           20224
# SDN           20244
# GBR           20249
# FIN           20291
# CHE           20350
# SWE           20364
# PAK           20368
# HUN           20418
# LKA           20528
# EGY           20549
# TUN           20672
# GTM           20704
# DOM           20705
# JOR           20746
# SLV           20930
# BGR           20992
# PHL           21094
# ZAF           21125
# TUR           21154
# MUS           21191
# IDN           21224
# THA           21235
# CRI           21239
# MAR           21240
# ARG           21258
# ROU           21386
# IND           21431
# PER           21439
# BRA           21560
# MEX           21744
# COL           21915
# MKD           23255
# NLD           24037
# USA           24664
# BOL           25470

# %%
# Only including countries that have more than 15000 values
countires_to_include = vals_per_country[vals_per_country[0] >= 15000].index
print (len(countires_to_include))
m2 = master[master.country_code.isin(countires_to_include)]
print (len(m2.country_code.unique()))
# Out:
# 153
# 153

# %%
# After applying the exclusion thershold
print (master.shape)
print (m2.shape)
# Out:
# (5854, 1091)
# (4626, 1091)

# %%
avg_vals_per_country = pd.DataFrame(m2.groupby('country_code').count().mean())
avg_vals_per_country.sort_values(by=0).head(500)
# Out:
# Students enrolled in secondary education (thous...  4.5163
# Index of industrial production: Mining (Index b...  4.5163
# Index of industrial production: Textiles, weari...  4.5294
# Consumer price index: Food                          4.5294
# Index of industrial production: Chemicals, petr...  4.5752
# Total population of concern to UNHCR (number)       4.5948
# Ratio of girls to boys in primary education         4.6078
# Public private partnerships investment in energ...  4.6340
# Index of industrial production: Food, beverages...  4.6797
# Malaria incidence (per 1,000 people at risk)        4.7190
# Poverty headcount ratio at national poverty lin...  4.7647
# Imputed social contributions revenue                4.8366
# Changes in stocks (petajoules)                      4.9346
# Revenue from sales of market establishments         4.9739
# Electricity production from nuclear sources (% ...  4.9869
# Gross enrollment ratio - Primary (female)           5.0000
# Gross enrollement ratio - Primary (male)            5.0000
# Battle-related deaths (number of people)            5.0588
# Sales taxes                                         5.0588
# Agricultural irrigated land (% of total agricul...  5.1242
# Students enrolled in primary education (thousands)  5.1765
# Index of industrial production: Manufacturing (...  5.1830
# Output gap in percent of potential GDP              5.1895
# Tourism expenditure (millions of US dollars)        5.2092
# International student mobility (% of total tert...  5.2353
# Other taxes on int trade & transactions             5.2745
# Tourist/visitor arrivals (thousands)                5.2876
# Research and development expenditure (% of GDP)_x   5.3007
# Youth not in school or employment (% ages 15-24)    5.3072
# Ratio of education and health expenditure to mi...  5.3725
# Taxes on exports (% of tax revenue)                 5.4575
# Taxes on exports (current LCU)                      5.4771
# Investment in energy with private participation...  5.6144
# Net bilateral aid flows from DAC donors, Poland...  5.6471
# Proportion of births attended by skilled health...  5.6797
# Contraceptive prevalence, any methods (% of wom...  5.6863
# Emissions per capita (metric tons of carbon dio...  5.6928
# Survival rate to the last grade of lower second...  5.6928
# Primary school dropout rate (% of primary schoo...  5.6993
# Domestic general government health expenditure ...  5.7516
# Current health expenditure (% of GDP)               5.7516
# Vitamin A supplementation coverage rate (% of c...  5.7778
# Recurrent taxes on net wealth                       5.7843
# Food production (Index Base: 2004-2006 = 100)       5.7908
# Agricultural production (Index Base: 2004-2006 ...  5.7908
# Emissions (thousand metric tons of carbon dioxide)  5.8235
# Grants revenue from int orgs: capital               5.9085
# Net migration                                       5.9608
# Revenue from other transfers: capital               6.0000
# Internally displaced persons, new displacement ...  6.0392
# Consumer price index: General                       6.0719
# Net bilateral aid flows from DAC donors, Portug...  6.2092
# PPG, bonds (NFL, current US$)                       6.3399
# Grants revenue from int orgs: current               6.4314
# Taxes on exports                                    6.4706
# Self/non-employed social contributions revenue      6.4771
# PM2.5 pollution, population exposed to levels e...  6.5033
# Grants revenue from foreign govts: capital          6.5948
# Net bilateral aid flows from DAC donors, Czech ...  6.6275
# Percentage of individuals using the internet        6.6667
# Portfolio investment, bonds (PPG + PNG) (NFL, c...  6.7190
# Employment                                          6.7908
# Fertilizer consumption (% of fertilizer product...  6.8824
# Net migration rate (per 1,000 people)               6.9804
# Revenue from sales of nonmarket establishments      7.0000
# Taxes on payroll & workforce                        7.0065
# Government expenditure on education (% of GDP)      7.0523
# Legislation exists on domestic violence (1=yes;...  7.1046
# Median age (years)                                  7.1373
# Sex ratio at birth (male to female births)          7.1438
# Seats held by women in national parliament, as ...  7.1503
# Grants in cash                                      7.2680
# Poverty headcount ratio at $1.90 a day (2011 PP...  7.4641
# Primary energy production (petajoules)              7.4706
# Total debt service (% of exports of goods, serv...  7.4837
# New businesses registered (number)                  7.5033
# New business density (new registrations per 1,0...  7.5033
# Carbon dioxide emissions, per capita (tonnes)       7.5229
# Carbon dioxide emissions (kg per 2010 US$ of GDP)   7.5817
# Net imports [Imports - Exports - Bunkers] (peta...  7.6209
# Supply per capita (gigajoules)                      7.6209
# Total supply (petajoules)                           7.6209
# Fossil fuel energy consumption (% of total ener...  7.6536
# Net official flows from UN agencies, UNAIDS (cu...  7.6536
# Central government debt, total (% of GDP)           7.6928
# Central government debt, total (current LCU)        7.6928
# Net official development assistance received (%...  7.7190
# Inequality-adjusted HDI (IHDI)                      7.8235
# Overall loss in HDI due to inequality (%)           7.8235
# Coefficient of human inequality                     7.8235
# Cost of business start-up procedures (% of GNI ...  7.9216
# Trademark applications, nonresident, by count       7.9281
# Inequality-adjusted income index                    7.9412
# Grants revenue from int orgs                        7.9412
# Prison population (per 100,000 people)              7.9412
# Inequality in income (%)                            7.9412
# Trademark applications, resident, by count          7.9673
# Skilled labour force (% of labour force)            8.0458
# Concentration index (exports) (value)               8.0980
# Poverty headcount ratio at $3.20 a day (2011 PP...  8.1111
# Other social contributions revenue                  8.1569
# Inequality-adjusted education index                 8.1569
# Inequality in education (%)                         8.1569
# Proportion of undernourished in the population (%)  8.1895
# Government expenditure per student, secondary (...  8.3007
# Gross enrolment ratio, tertiary (% of tertiary ...  8.4052
# Homicide rate (per 100,000 people)                  8.4314
# Pupil-teacher ratio, primary school (pupils per...  8.5033
# Government expenditure per student, tertiary (%...  8.5163
# Poverty headcount ratio at $5.50 a day (2011 PP...  8.6013
# Gross enrolment ratio, pre-primary (% of presch...  8.6797
# Taxes on estate, inheritance, & gifts               8.6928
# Income share held by lowest 20%                     8.7124
# Grants revenue from other gen govt: capital         8.8889
# Gross enrolment ratio, secondary (% of secondar...  8.9085
# PM2.5 pollution, population exposed to levels e...  9.0000
# High-technology exports (% of manufactured expo...  9.0261
# Grants revenue from foreign govts: current          9.0392
# High-technology exports (current US$)               9.0588
# Inequality-adjusted life expectancy index           9.0915
# Inequality in life expectancy (%)                   9.0915
# Current health expenditure (% of GDP)_x             9.0980
# Social security contributions: revenue employees    9.3660
# IFC, private nonguaranteed (NFL, current US$)       9.4052
# Quality of port infrastructure, WEF (1=extremel...  9.4967
# Burden of customs procedure, WEF (1=extremely i...  9.4967
# Nurses and midwives (per 1,000 people)              9.5033
# Taxes on income, profits, & capital gains: other    9.5556
# Taxes on use of/permission to use goods: vehicles   9.6405
# Pupil-teacher ratio, upper secondary                9.6667
# Working poor at PPP$3.20 a day (% of total empl...  9.7124
# Social security contributions revenue: employers    9.7712
# Renewable energy consumption (% of total final ...  9.8170
# Natural resource depletion (% of GNI)               9.8431
# HIV prevalence, adult (% ages 15-49)                9.9673
# Maternal mortality ratio (deaths per 100,000 li... 10.1242
# Tuberculosis incidence (per 100,000 people)        10.1373
# Gross enrolment ratio, primary (% of primary sc... 10.1699
# Discrepancy in expenditure estimate of GDP (con... 10.2157
# Net financial flows, IMF nonconcessional (NFL, ... 10.2418
# Pupil-teacher ratio, lower secondary               10.2614
# Adjusted net savings (% of GNI)                    10.3007
# Internet users, total (% of population)            10.4052
# Private capital flows (% of GDP)                   10.4706
# Other taxes on goods & services                    10.5294
# Gender Inequality Index (GII)                      10.6797
# International inbound tourists (thousands)         10.6863
# Rent revenue                                       10.6928
# Rural population with access to electricity (%)    10.7908
# Taxes on use of/permission to use goods: other     10.8562
# Stocks traded, turnover ratio of domestic share... 10.8824
# Intentional homicides, female (per 100,000 female) 10.9020
# Forest area (% of total land area)                 10.9216
# Grants revenue from other gen govt: current        10.9412
# Intentional homicides, male (per 100,000 male)     10.9673
# Mobile phone subscriptions (per 100 people)        10.9935
# Source data assessment of statistical capacity ... 11.0654
# Statistical Capacity score (Overall average)       11.1046
# Periodicity and timeliness assessment of statis... 11.1046
# Methodology assessment of statistical capacity ... 11.1046
# Share of tariff lines with specific rates, prim... 11.1438
# PNG, commercial banks and other creditors (NFL,... 11.1699
# Share of tariff lines with specific rates, manu... 11.1895
# Revenue from other transfers: current              11.2353
# PM2.5 pollution, population exposed to levels e... 11.2745
# Gender Development Index (GDI)                     11.3007
# Dividend revenue                                   11.3072
# Human Development Index (HDI), male                11.3137
# Human Development Index (HDI), female              11.3137
# Net flows on external debt, private nonguarante... 11.3529
# Expenditure on secondary education (% of govern... 11.3791
# Expenditure on primary education (% of governme... 11.4052
# Liner shipping connectivity index (maximum valu... 11.4314
# Taxes on financial & capital transactions          11.5686
# Market capitalization of listed domestic compan... 11.5882
# Market capitalization of listed domestic compan... 11.6078
# Research and development expenditure (% of GDP)_y  11.6078
# Tertiary education, academic staff (% female)      11.6471
# External debt stocks, private nonguaranteed (PN... 11.7386
# Mortality rate, female adult (per 1,000 people)    11.7647
# Mortality rate, male adult (per 1,000 people)      11.7647
# Population ages 65 and older (millions)            11.8301
# Remittances, inflows (% of GDP)                    11.8366
# Domestic credit provided by financial sector (%... 11.9085
# PPG, IBRD (DOD, current US$)                       11.9804
# PM2.5 air pollution, population exposed to leve... 11.9804
# Children out of school, female (% of female pri... 12.0131
# Children out of school, male (% of male primary... 12.0131
# Electricity production from coal sources (% of ... 12.0327
# Children out of school, primary, female            12.0458
# Children out of school, primary, male              12.0458
# Adjusted net enrollment rate, primary, female (... 12.0588
# Grants revenue from foreign govts                  12.0654
# Adjusted net enrollment rate, primary, male (% ... 12.0654
# Population with at least some secondary educati... 12.0719
# Mortality rate, under-five (per 1,000 live births) 12.1242
# PM2.5 air pollution, mean annual exposure (micr... 12.1242
# Gross fixed capital formation (% of GDP)_x         12.1242
# Mortality rate, infant (per 1,000 live births)_x   12.1242
# Population with at least some secondary educati... 12.1569
# S&P Global Equity Indices (annual % change)        12.1634
# Population with at least some secondary educati... 12.1699
# Estimated gross national income per capita, fem... 12.1895
# Estimated gross national income per capita, mal... 12.1895
# External health expenditure per capita, PPP (cu... 12.1961
# External health expenditure per capita (current... 12.1961
# External health expenditure (% of current healt... 12.1961
# Interest revenue                                   12.2222
# Expected years of schooling, male (years)          12.2353
# Expected years of schooling, female (years)        12.2353
# Foreign direct investment, net inflows (% of GD... 12.2614
# Net official flows from UN agencies, WFP (curre... 12.3007
# Share of seats in parliament (% held by women)     12.3725
# Population under age 5 (millions)                  12.4444
# Value-added taxes                                  12.4444
# School enrollment, primary, female (% net)         12.4510
# School enrollment, primary, male (% net)           12.4510
# General government net debt                        12.4837
# Exports and imports (% of GDP)                     12.5033
# Revenue from fines, penalties & forfeits           12.5686
# Stocks traded, total value (% of GDP)              12.6275
# Stocks traded, total value (current US$)           12.6601
# Mean years of schooling, male (years)              12.6863
# Mean years of schooling, female (years)            12.6993
# General government structural balance              12.7320
# Grants revenue from other gen govt                 12.9020
# Expenditure on tertiary education (% of governm... 12.9608
# Infants lacking immunization, measles (% of one... 12.9673
# Infants lacking immunization, DPT (% of one-yea... 12.9673
# Net official flows from UN agencies, UNHCR (cur... 13.0131
# Share of tariff lines with specific rates, all ... 13.0784
# Social security contributions revenue              13.1046
# Electricity production from renewable sources, ... 13.1242
# Electricity production from renewable sources, ... 13.1242
# Gross domestic product (GDP), total (2011 PPP $... 13.1373
# GDP per capita (2011 PPP $)                        13.1373
# Unemployment, youth (% ages 15–24)                 13.2026
# Unemployment, total (% of labour force)            13.2026
# Vulnerable employment (% of total employment)      13.2026
# Total unemployment rate (female to male ratio)     13.2026
# Youth unemployment rate (female to male ratio)     13.2026
# Share of employment in nonagriculture, female (... 13.2026
# Employment to population ratio (% ages 15 and o... 13.2026
# Employment in services (% of total employment)     13.2026
# Employment in agriculture (% of total employment)  13.2026
# Young age (0-14) dependency ratio (per 100 peop... 13.2092
# Population ages 15–64 (millions)                   13.2092
# Adolescent birth rate (births per 1,000 women a... 13.2092
# Old-age (65 and older) dependency ratio (per 10... 13.2092
# Urban population (%)                               13.2092
# Total population (millions)                        13.2092
# Life expectancy at birth, male (years)             13.2092
# Labour force participation rate (% ages 15 and ... 13.2092
# Labour force participation rate (% ages 15 and ... 13.2092
# Labour force participation rate (% ages 15 and ... 13.2092
# Life expectancy at birth, female (years)           13.2092
# Births attended by skilled health staff (% of t... 13.3268
# Automated teller machines (ATMs) (per 100,000 a... 13.3333
# PPG, commercial banks (NFL, current US$)           13.3595
# PPG, other private creditors (NFL, current US$)    13.4641
# Listed domestic companies, total                   13.5752
# Lower secondary completion rate, female (% of r... 13.5817
# Lower secondary completion rate, male (% of rel... 13.5817
# Recurrent taxes on immovable property              13.6209
# Hunger Index                                       13.6471
# Net financial flows, RDB concessional (NFL, cur... 13.6667
# Revenue from administrative fees                   13.7059
# Secondary education, teachers (% female)           13.7059
# Fertilizer consumption (kilograms per hectare o... 13.7190
# Business extent of disclosure index (0=less dis... 13.8431
# Secondary education, teachers, female              13.8562
# Net financial flows, RDB nonconcessional (NFL, ... 13.8889
# Taxes on specific services                         14.0131
# Pupil-teacher ratio, tertiary                      14.0327
# Scientific and technical journal articles          14.0392
# Commercial bank branches (per 100,000 adults)      14.3007
# Net financial flows, IBRD (NFL, current US$)       14.5163
# Revenue from other transfers                       14.5294
# Lower secondary completion rate, total (% of re... 14.5817
# Government expenditure on education, total (% o... 14.6471
# Pupil-teacher ratio, secondary                     14.6993
# Prevalence of wasting in\n children under five ... 14.7778
# Prevalence of stunting in\n children under five... 14.7778
# Other expense (% of expense)                       14.8235
# Machinery and transport equipment (% of value a... 14.9020
# Net financial flows, IDA (NFL, current US$)        14.9150
# Other expense (current LCU)                        14.9412
# PPG, IDA (DOD, current US$)                        14.9673
# Start-up procedures to register a business (num... 14.9804
# Electricity production from natural gas sources... 15.0000
# Social contributions                               15.0980
# Sex ratio at birth (male births per female births) 15.1503
# Charges for the use of intellectual property, r... 15.2810
# Chemicals (% of value added in manufacturing)      15.2876
# Secondary education, teachers                      15.3072
# CO2 emissions from gaseous fuel consumption (kt)   15.4967
# CO2 emissions from gaseous fuel consumption (% ... 15.4967
# Food, beverages and tobacco (% of value added i... 15.7320
# Textiles and clothing (% of value added in manu... 15.7386
# Changes in inventories (constant LCU)              15.7582
# Government expenditure on education, total (% o... 15.8301
# Physicians (per 1,000 people)                      15.8366
# Tuberculosis treatment success rate (% of new c... 15.8824
# Bound rate, simple mean, manufactured products (%) 15.9216
# Bound rate, simple mean, primary products (%)      15.9216
# Other manufacturing (% of value added in manufa... 15.9346
# PPG, private creditors (NFL, current US$)          16.0000
# Bound rate, simple mean, all products (%)          16.0196
# Net investment in nonfinancial assets (% of GDP)   16.1046
# Binding coverage, primary products (%)             16.1176
# Binding coverage, manufactured products (%)        16.1176
# Net investment in nonfinancial assets (current ... 16.1634
# Gross capital formation (% of GDP)_x               16.1895
# Primary completion rate, female (% of relevant ... 16.2026
# Primary completion rate, male (% of relevant ag... 16.2026
# Binding coverage, all products (%)                 16.2157
# Newborns protected against tetanus (%)             16.2288
# Repeaters, primary, female (% of female enrollm... 16.2549
# Repeaters, primary, male (% of male enrollment)    16.2614
# Subsidies and other transfers (% of expense)       16.4118
# Short-term debt (% of exports of goods, service... 16.5163
# Over-age students, primary, female (% of female... 16.5621
# Over-age students, primary, male (% of male enr... 16.5752
# Subsidies and other transfers (current LCU)        16.5817
# Adjusted net enrollment rate, primary (% of pri... 16.6144
# Portfolio equity, net inflows (BoP, current US$)   16.6209
# Children out of school (% of primary school age)   16.6275
# Children out of school, primary                    16.6928
# Commercial banks and other lending (PPG + PNG) ... 16.7386
# Other taxes n.e.c.                                 16.7516
# Public and publicly guaranteed debt service (% ... 16.8039
# Short-term debt (% of total reserves)              16.8170
# Access to clean fuels and technologies for cook... 16.8627
# Taxes on use of/permission to use goods            16.8627
# Out-of-pocket expenditure per capita, PPP (curr... 16.9216
# Out-of-pocket expenditure per capita (current US$) 16.9216
# Out-of-pocket expenditure (% of current health ... 16.9281
# Taxes on property                                  16.9346
# Domestic general government health expenditure ... 17.0131

# %%
# Removing any columns that have less than an average of 5 values per country
predictors_to_include = avg_vals_per_country[avg_vals_per_country[0] >= 5.0].index[2:]
predictors_to_include = pd.DataFrame(predictors_to_include, columns = ['ind'])

# %%
# Removing all columns that have "LCU" or local currency units
predictors_to_include = predictors_to_include[~predictors_to_include.ind.str.contains ('LCU')] 
predictors_to_include
# Out:
#                                                    ind
# 0    Access to clean fuels and technologies for coo...
# 1    Adjusted net enrollment rate, primary (% of pr...
# 2    Adjusted net enrollment rate, primary, female ...
# 3    Adjusted net enrollment rate, primary, male (%...
# 4                      Adjusted net savings (% of GNI)
# ..                                                 ...
# 907  Wage and salaried workers, total (% of total e...
# 908  Working poor at PPP$3.20 a day (% of total emp...
# 909  Young age (0-14) dependency ratio (per 100 peo...
# 910   Youth not in school or employment (% ages 15-24)
# 911     Youth unemployment rate (female to male ratio)
#
# [850 rows x 1 columns]

# %%
# Removing other superfluous columns
remove_superfluous_cols = ['Agriculture, forestry, and fishing, value added (current US$)',
                           'Changes in inventories (current US$)',
                           'Changes in stocks (petajoules)',
                           'Consumer price index: General',
                           'Current health expenditure (% of GDP)_x',
                           'Current health expenditure (% of GDP)_y',
                           'Foreign direct investment, net inflows (% of GDP)_x',
                           'GDP (current US$)'
                          ]
predictors_to_include = predictors_to_include[~predictors_to_include.ind.isin (remove_superfluous_cols)] 
list(predictors_to_include.ind.values)
# Out:
#  'Net financial flows, IMF nonconcessional (NFL, current US$)',
#  'Net financial flows, RDB concessional (NFL, current US$)',
#  'Net financial flows, RDB nonconcessional (NFL, current US$)',
#  'Net financial flows, bilateral (NFL, current US$)',
#  'Net financial flows, multilateral (NFL, current US$)',
#  'Net financial flows, others (NFL, current US$)',
#  'Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
#  'Net imports [Imports - Exports - Bunkers] (petajoules)',
#  'Net investment in nonfinancial assets (% of GDP)',
#  'Net migration',
#  'Net migration rate (per 1,000 people)',
#  'Net official development assistance received (% of GNI)',
#  'Net official flows from UN agencies, UNAIDS (current US$)',
#  'Net official flows from UN agencies, UNHCR (current US$)',
#  'Net official flows from UN agencies, WFP (current US$)',
#  'Net primary income (BoP, current US$)',
#  'Net primary income (Net income from abroad) (current US$)',
#  'Net secondary income (BoP, current US$)',
#  'Net secondary income (Net current transfers from abroad) (current US$)',
#  'Net trade in goods (BoP, current US$)',
#  'Net trade in goods and services (BoP, current US$)',
#  'New business density (new registrations per 1,000 people ages 15-64)',
#  'New businesses registered (number)',
#  'Newborns protected against tetanus (%)',
#  'Nitrous oxide emissions (% change from 1990)',
#  'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#  'Number of infant deaths',
#  'Number of neonatal deaths',
#  'Number of under-five deaths',
#  'Nurses and midwives (per 1,000 people)',
#  'Old-age (65 and older) dependency ratio (per 100 people ages 15-64)',
#  'Ores and metals exports (% of merchandise exports)',
#  'Ores and metals imports (% of merchandise imports)',
#  'Other expense (% of expense)',
#  'Other greenhouse gas emissions (% change from 1990)',
#  'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#  'Other manufacturing (% of value added in manufacturing)',
#  'Other revenue',
#  'Other social contributions revenue',
#  'Other taxes n.e.c.',
#  'Other taxes on goods & services',
#  'Other taxes on int trade & transactions',
#  'Out-of-pocket expenditure (% of current health expenditure)',
#  'Out-of-pocket expenditure per capita (current US$)',
#  'Out-of-pocket expenditure per capita, PPP (current international $)',
#  'Output gap in percent of potential GDP',
#  'Over-age students, primary (% of enrollment)',
#  'Over-age students, primary, female (% of female enrollment)',
#  'Over-age students, primary, male (% of male enrollment)',
#  'Overall loss in HDI due to inequality (%)',
#  'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#  'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
#  'PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)',
#  'PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)',
#  'PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
#  'PNG, commercial banks and other creditors (NFL, current US$)',
#  'PPG, IBRD (DOD, current US$)',
#  'PPG, IDA (DOD, current US$)',
#  'PPG, bonds (NFL, current US$)',
#  'PPG, commercial banks (NFL, current US$)',
#  'PPG, official creditors (NFL, current US$)',
#  'PPG, other private creditors (NFL, current US$)',
#  'PPG, private creditors (NFL, current US$)',
#  'Percentage of individuals using the internet',
#  'Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
#  'Permanent cropland (% of land area)',
#  'Personal remittances, paid (current US$)',
#  'Personal remittances, received (% of GDP)',
#  'Personal remittances, received (current US$)',
#  'Personal transfers, receipts (BoP, current US$)',
#  'Physicians (per 1,000 people)',
#  'Population',
#  'Population ages 0-14 (% of total population)',
#  'Population ages 0-14, female',
#  'Population ages 0-14, female (% of female population)',
#  'Population ages 0-14, male',
#  'Population ages 0-14, male (% of male population)',
#  'Population ages 0-14, total',
#  'Population ages 00-04, female (% of female population)',
#  'Population ages 00-04, male (% of male population)',
#  'Population ages 05-09, female (% of female population)',
#  'Population ages 05-09, male (% of male population)',
#  'Population ages 10-14, female (% of female population)',
#  'Population ages 10-14, male (% of male population)',
#  'Population ages 15-19, female (% of female population)',
#  'Population ages 15-19, male (% of male population)',
#  'Population ages 15-64 (% of total population)',
#  'Population ages 15-64, female',
#  'Population ages 15-64, female (% of female population)',
#  'Population ages 15-64, male',
#  'Population ages 15-64, male (% of male population)',
#  'Population ages 15-64, total',
#  'Population ages 15–64 (millions)',
#  'Population ages 20-24, female (% of female population)',
#  'Population ages 20-24, male (% of male population)',
#  'Population ages 25-29, female (% of female population)',
#  'Population ages 25-29, male (% of male population)',
#  'Population ages 30-34, female (% of female population)',
#  'Population ages 30-34, male (% of male population)',
#  'Population ages 35-39, female (% of female population)',
#  'Population ages 35-39, male (% of male population)',
#  'Population ages 40-44, female (% of female population)',
#  'Population ages 40-44, male (% of male population)',
#  'Population ages 45-49, female (% of female population)',
#  'Population ages 45-49, male (% of male population)',
#  'Population ages 50-54, female (% of female population)',
#  'Population ages 50-54, male (% of male population)',
#  'Population ages 55-59, female (% of female population)',
#  'Population ages 55-59, male (% of male population)',
#  'Population ages 60-64, female (% of female population)',
#  'Population ages 60-64, male (% of male population)',
#  'Population ages 65 and above (% of total population)',
#  'Population ages 65 and above, female',
#  'Population ages 65 and above, female (% of female population)',
#  'Population ages 65 and above, male',
#  'Population ages 65 and above, male (% of male population)',
#  'Population ages 65 and above, total',
#  'Population ages 65 and older (millions)',
#  'Population ages 65-69, female (% of female population)',
#  'Population ages 65-69, male (% of male population)',
#  'Population ages 70-74, female (% of female population)',
#  'Population ages 70-74, male (% of male population)',
#  'Population ages 75-79, female (% of female population)',
#  'Population ages 75-79, male (% of male population)',
#  'Population ages 80 and above, female (% of female population)',
#  'Population ages 80 and above, male (% of male population)',
#  'Population density (people per sq. km of land area)',
#  'Population growth (annual %)',
#  'Population in largest city',
#  'Population in the largest city (% of urban population)',
#  'Population in urban agglomerations of more than 1 million',
#  'Population in urban agglomerations of more than 1 million (% of total population)',
#  'Population under age 5 (millions)',
#  'Population using at least basic drinking-water services (%)',
#  'Population using at least basic sanitation services (%)',
#  'Population with at least some secondary education (% ages 25 and older)',
#  'Population with at least some secondary education, female (% ages 25 and older)',
#  'Population with at least some secondary education, male (% ages 25 and older)',
#  'Population, female',
#  'Population, female (% of total population)',
#  'Population, male',
#  'Population, male (% of total population)',
#  'Population, total',
#  'Portfolio equity, net inflows (BoP, current US$)',
#  'Portfolio investment, bonds (PPG + PNG) (NFL, current US$)',
#  'Portfolio investment, net (BoP, current US$)',
#  'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
#  'Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)',
#  'Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)',
#  'Preprimary education, duration (years)',
#  'Prevalence of HIV, total (% of population ages 15-49)',
#  'Prevalence of anemia among children (% of children under 5)',
#  'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
#  'Prevalence of anemia among pregnant women (%)',
#  'Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
#  'Prevalence of stunting in\n children under five years (%)',
#  'Prevalence of wasting in\n children under five years (%)',
#  'Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#  'Primary completion rate, female (% of relevant age group)',
#  'Primary completion rate, male (% of relevant age group)',
#  'Primary completion rate, total (% of relevant age group)',
#  'Primary education, duration (years)',
#  'Primary education, pupils',
#  'Primary education, pupils (% female)',
#  'Primary education, teachers',
#  'Primary energy production (petajoules)',
#  'Primary income payments (BoP, current US$)',
#  'Primary income receipts (BoP, current US$)',
#  'Primary school dropout rate (% of primary school cohort)',
#  'Primary school starting age (years)',
#  'Prison population (per 100,000 people)',
#  'Private capital flows (% of GDP)',
#  'Property income revenue',
#  'Proportion of births attended by skilled health personnel (%)',
#  'Proportion of seats held by women in national parliaments (%)',
#  'Proportion of undernourished in the population (%)',
#  'Public and publicly guaranteed debt service (% of GNI)',
#  'Public and publicly guaranteed debt service (% of exports of goods, services and primary income)',
#  'Pupil-teacher ratio, lower secondary',
#  'Pupil-teacher ratio, primary',
#  'Pupil-teacher ratio, primary school (pupils per teacher)',
#  'Pupil-teacher ratio, secondary',
#  'Pupil-teacher ratio, tertiary',
#  'Pupil-teacher ratio, upper secondary',
#  'Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficient by international standards)',
#  'Ratio of education and health expenditure to military expenditure',
#  'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#  'Real interest rate (%)',
#  'Recurrent taxes on immovable property',
#  'Recurrent taxes on net wealth',
#  'Refugee population by country or territory of asylum',
#  'Refugee population by country or territory of origin',
#  'Remittances, inflows (% of GDP)',
#  'Renewable electricity output (% of total electricity output)',
#  'Renewable energy consumption (% of total final energy consumption)_x',
#  'Renewable energy consumption (% of total final energy consumption)_y',
#  'Rent revenue',
#  'Repeaters, primary, female (% of female enrollment)',
#  'Repeaters, primary, male (% of male enrollment)',
#  'Repeaters, primary, total (% of total enrollment)',
#  'Research and development expenditure (% of GDP)_x',
#  'Research and development expenditure (% of GDP)_y',
#  'Reserves and related items (BoP, current US$)',
#  'Revenue',
#  'Revenue from administrative fees',
#  'Revenue from fines, penalties & forfeits',
#  'Revenue from other transfers',
#  'Revenue from other transfers: capital',
#  'Revenue from other transfers: current',
#  'Revenue from sales of goods & services',
#  'Revenue from sales of nonmarket establishments',
#  'Revenue, excluding grants (% of GDP)',
#  'Rural population',
#  'Rural population (% of total population)',
#  'Rural population growth (annual %)',
#  'Rural population with access to electricity (%)',
#  'S&P Global Equity Indices (annual % change)',
#  'Sales taxes',
#  'School enrollment, preprimary (% gross)',
#  'School enrollment, preprimary, female (% gross)',
#  'School enrollment, preprimary, male (% gross)',
#  'School enrollment, primary (% gross)',
#  'School enrollment, primary (% net)',
#  'School enrollment, primary (gross), gender parity index (GPI)',
#  'School enrollment, primary and secondary (gross), gender parity index (GPI)',
#  'School enrollment, primary, female (% gross)',
#  'School enrollment, primary, female (% net)',
#  'School enrollment, primary, male (% gross)',
#  'School enrollment, primary, male (% net)',
#  'School enrollment, secondary (% gross)',
#  'School enrollment, tertiary (% gross)',
#  'School enrollment, tertiary (gross), gender parity index (GPI)',
#  'School enrollment, tertiary, female (% gross)',
#  'School enrollment, tertiary, male (% gross)',
#  'Scientific and technical journal articles',
#  'Seats held by women in national parliament, as of February (%)',
#  'Secondary education, duration (years)',
#  'Secondary education, general pupils',
#  'Secondary education, general pupils (% female)',
#  'Secondary education, teachers',
#  'Secondary education, teachers (% female)',
#  'Secondary education, teachers, female',
#  'Secondary education, vocational pupils',
#  'Secondary education, vocational pupils (% female)',
#  'Secondary income receipts (BoP, current US$)',
#  'Secondary income, other sectors, payments (BoP, current US$)',
#  'Self-employed, female (% of female employment) (modeled ILO estimate)',
#  'Self-employed, male (% of male employment) (modeled ILO estimate)',
#  'Self-employed, total (% of total employment) (modeled ILO estimate)',
#  'Self/non-employed social contributions revenue',
#  'Service exports (BoP, current US$)',
#  'Service imports (BoP, current US$)',
#  'Services, value added (% of GDP)',
#  'Services, value added (annual % growth)',
#  'Services, value added (constant 2010 US$)',
#  'Services, value added per worker (constant 2010 US$)',
#  'Sex ratio at birth (male births per female births)',
#  'Sex ratio at birth (male to female births)',
#  'Share of employment in nonagriculture, female (% of total employment in nonagriculture)',
#  'Share of seats in parliament (% held by women)',
#  'Share of tariff lines with international peaks, all products (%)',
#  'Share of tariff lines with international peaks, manufactured products (%)',
#  'Share of tariff lines with international peaks, primary products (%)',
#  'Share of tariff lines with specific rates, all products (%)',
#  'Share of tariff lines with specific rates, manufactured products (%)',
#  'Share of tariff lines with specific rates, primary products (%)',
#  'Short-term debt (% of exports of goods, services and primary income)',
#  'Short-term debt (% of total external debt)',
#  'Short-term debt (% of total reserves)',
#  'Skilled labour force (% of labour force)',
#  'Social contributions',
#  'Social security contributions revenue',
#  'Social security contributions revenue: employers',
#  'Social security contributions: revenue employees',
#  'Source data assessment of statistical capacity (scale 0 - 100)',
#  'Start-up procedures to register a business (number)',
#  'Statistical Capacity score (Overall average)',
#  'Stocks traded, total value (% of GDP)',
#  'Stocks traded, total value (current US$)',
#  'Stocks traded, turnover ratio of domestic shares (%)',
#  'Students enrolled in primary education (thousands)',
#  'Subsidies and other transfers (% of expense)',
#  'Supply per capita (gigajoules)',
#  'Surface area (sq. km)',
#  'Survival rate to the last grade of lower secondary general education (%)',
#  'Tariff rate, applied, simple mean, all products (%)',
#  'Tariff rate, applied, simple mean, manufactured products (%)',
#  'Tariff rate, applied, simple mean, primary products (%)',
#  'Tariff rate, applied, weighted mean, all products (%)',
#  'Tariff rate, applied, weighted mean, manufactured products (%)',
#  'Tariff rate, applied, weighted mean, primary products (%)',
#  'Tariff rate, most favored nation, simple mean, all products (%)',
#  'Tariff rate, most favored nation, simple mean, manufactured products (%)',
#  'Tariff rate, most favored nation, simple mean, primary products (%)',
#  'Tariff rate, most favored nation, weighted mean, all products (%)',
#  'Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#  'Tariff rate, most favored nation, weighted mean, primary products (%)',
#  'Tax revenue',
#  'Taxes less subsidies on products (current US$)',
#  'Taxes on estate, inheritance, & gifts',
#  'Taxes on exports',
#  'Taxes on exports (% of tax revenue)',
#  'Taxes on financial & capital transactions',
#  'Taxes on goods & services',
#  'Taxes on income, profits, & capital gains',
#  'Taxes on income, profits, & capital gains: corporations',
#  'Taxes on income, profits, & capital gains: individuals',
#  'Taxes on income, profits, & capital gains: other',
#  'Taxes on int trade & transactions',
#  'Taxes on payroll & workforce',
#  'Taxes on property',
#  'Taxes on specific services',
#  'Taxes on use of/permission to use goods',
#  'Taxes on use of/permission to use goods: other',
#  'Taxes on use of/permission to use goods: vehicles',
#  'Tertiary education, academic staff (% female)',
#  'Textiles and clothing (% of value added in manufacturing)',
#  'Total debt service (% of GNI)',
#  'Total debt service (% of exports of goods, services and primary income)_x',
#  'Total debt service (% of exports of goods, services and primary income)_y',
#  'Total fisheries production (metric tons)',
#  'Total greenhouse gas emissions (% change from 1990)',
#  'Total greenhouse gas emissions (kt of CO2 equivalent)',
#  'Total investment',
#  'Total population (millions)',
#  'Total reserves (% of total external debt)',
#  'Total reserves (includes gold, current US$)',
#  'Total reserves in months of imports',
#  'Total reserves minus gold (current US$)',
#  'Total supply (petajoules)',
#  'Total unemployment rate (female to male ratio)',
#  'Tourism expenditure (millions of US dollars)',
#  'Tourist/visitor arrivals (thousands)',
#  'Trade (% of GDP)',
#  'Trade in services (% of GDP)',
#  'Trade value of exports',
#  'Trademark applications, nonresident, by count',
#  'Trademark applications, resident, by count',
#  'Transport services (% of commercial service exports)',
#  'Transport services (% of commercial service imports)',
#  'Transport services (% of service exports, BoP)',
#  'Transport services (% of service imports, BoP)',
#  'Travel services (% of commercial service exports)',
#  'Travel services (% of commercial service imports)',
#  'Travel services (% of service exports, BoP)',
#  'Travel services (% of service imports, BoP)',
#  'Tuberculosis incidence (per 100,000 people)',
#  'Tuberculosis treatment success rate (% of new cases)',
#  'Unemployment rate',
#  'Unemployment, female (% of female labor force) (modeled ILO estimate)',
#  'Unemployment, male (% of male labor force) (modeled ILO estimate)',
#  'Unemployment, total (% of labour force)',
#  'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#  'Unemployment, youth (% ages 15–24)',
#  'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#  'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#  'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#  'Unit value 95 percent interval - lower bound',
#  'Unit value 95 percent interval - upper bound',
#  'Unit value of exports',
#  'Urban population',
#  'Urban population (% of total population)',
#  'Urban population (%)',
#  'Urban population growth (annual %)',
#  'Use of IMF credit (DOD, current US$)',
#  'Value-added taxes',
#  'Vitamin A supplementation coverage rate (% of children ages 6-59 months)',
#  'Volume of Imports of goods',
#  'Volume of exports of goods',
#  'Volume of exports of goods and services',
#  'Volume of imports of goods and services',
#  'Vulnerable employment (% of total employment)',
#  'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#  'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#  'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#  'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#  'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#  'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#  'Working poor at PPP$3.20 a day (% of total employment)',
#  'Young age (0-14) dependency ratio (per 100 people ages 15-64)',
#  'Youth not in school or employment (% ages 15-24)',
#  'Youth unemployment rate (female to male ratio)']

# %%
# Creating master list of columns for imputation
new_columns = list(master.columns [0:3]) + list(predictors_to_include.ind.values)

# %%
# Creating new dataframe with just the list of new columns
m3 = m2[new_columns]
m3.reset_index(drop = True, inplace=True)
m3.head()
# Out:
#     nan
#
#    Total debt service (% of exports of goods, services and primary income)_y  \
# 0                                             8.1423
# 1                                            10.6811
# 2                                             6.1500
# 3                                             5.1216
# 4                                             8.1493
#
#    Total fisheries production (metric tons)  \
# 0                               133088.0000
# 1                               117104.0000
# 2                               113625.0000
# 3                               126200.0000
# 4                               132413.0000
#
#    Total greenhouse gas emissions (% change from 1990)  \
# 0                                                nan
# 1                                           -13.8672
# 2                                            27.9320
# 3                                           -21.7126
# 4                                           -12.1034
#
#    Total greenhouse gas emissions (kt of CO2 equivalent)  Total investment  \
# 0                                         50806.5427                5.7250
# 1                                         43761.0813               12.4920
# 2                                         64997.8399               21.0710
# 3                                         39775.1072               21.6190
# 4                                         44657.2433               21.0160
#
#    Total population (millions)  Total reserves (% of total external debt)  \
# 0                      11.8000                                        nan
# 1                          nan                                        nan
# 2                          nan                                        nan
# 3                          nan                                        nan
# 4                          nan                                        nan
#
#    Total reserves (includes gold, current US$)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Total reserves in months of imports  \
# 0                                  nan
# 1                                  nan
# 2                                  nan
# 3                                  nan
# 4                                  nan
#
#    Total reserves minus gold (current US$)  Total supply (petajoules)  \
# 0                                      nan                   238.0000
# 1                                      nan                        nan
# 2                                      nan                        nan
# 3                                      nan                        nan
# 4                                      nan                        nan
#
#    Total unemployment rate (female to male ratio)  \
# 0                                             nan
# 1                                          1.1800
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#    Tourism expenditure (millions of US dollars)  \
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
#
#    Tourist/visitor arrivals (thousands)  Trade (% of GDP)  \
# 0                                   nan               nan
# 1                                   nan               nan
# 2                                   nan               nan
# 3                                   nan               nan
# 4                                   nan               nan
#
#    Trade in services (% of GDP)  Trade value of exports  \
# 0                       17.0615           28375859.0523
# 1                       18.9593           25473418.7193
# 2                       26.3035           27343625.6520
# 3                       28.9094           26921210.7104
# 4                       38.5979           26782324.1071
#
#    Trademark applications, nonresident, by count  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Trademark applications, resident, by count  \
# 0                                         nan
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
#
#    Transport services (% of commercial service exports)  \
# 0                                            48.7616
# 1                                            41.3526
# 2                                            51.4820
# 3                                            40.5493
# 4                                            21.4314
#
#    Transport services (% of commercial service imports)  \
# 0                                            38.2859
# 1                                            31.0966
# 2                                            33.3636
# 3                                            31.3241
# 4                                            21.9930
#
#    Transport services (% of service exports, BoP)  \
# 0                                         29.0323
# 1                                         28.3409
# 2                                         34.2870
# 3                                         34.1871
# 4                                         21.4314
#
#    Transport services (% of service imports, BoP)  \
# 0                                         27.2829
# 1                                         29.3685
# 2                                         30.2789
# 3                                         28.1173
# 4                                         20.0581
#
#    Travel services (% of commercial service exports)  \
# 0                                            20.5882
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Travel services (% of commercial service imports)  \
# 0                                             2.9661
# 1                                             3.7538
# 2                                             4.0247
# 3                                             4.6790
# 4                                             6.1386
#
#    Travel services (% of service exports, BoP)  \
# 0                                      12.2581
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Travel services (% of service imports, BoP)  \
# 0                                       2.1137
# 1                                       3.5452
# 2                                       3.6526
# 3                                       4.2000
# 4                                       5.5986
#
#    Tuberculosis incidence (per 100,000 people)  \
# 0                                          nan
# 1                                          nan
# 2                                          nan
# 3                                          nan
# 4                                          nan
#
#    Tuberculosis treatment success rate (% of new cases)  Unemployment rate  \
# 0                                                nan                   nan
# 1                                                nan                   nan
# 2                                                nan                   nan
# 3                                                nan                   nan
# 4                                                nan                   nan
#
#    Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            24.4860
# 2                                            22.8520
# 3                                            22.9860
# 4                                            23.0180
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            20.7500
# 2                                            19.0320
# 3                                            19.5490
# 4                                            19.3330
#
#    Unemployment, total (% of labour force)  \
# 0                                      nan
# 1                                  22.6000
# 2                                      nan
# 3                                      nan
# 4                                      nan
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            22.6020
# 2                                            20.9250
# 3                                            21.2500
# 4                                            21.1590
#
#    Unemployment, youth (% ages 15–24)  \
# 0                                 nan
# 1                             53.0000
# 2                                 nan
# 3                                 nan
# 4                                 nan
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            56.4140
# 2                                            52.9260
# 3                                            53.2090
# 4                                            52.8750
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            49.6400
# 2                                            45.9990
# 3                                            47.1270
# 4                                            46.3490
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            53.0310
# 2                                            49.4680
# 3                                            50.1750
# 4                                            49.6220
#
#    Unit value 95 percent interval - lower bound  \
# 0                                       39.3014
# 1                                       38.6903
# 2                                       32.6086
# 3                                       38.8561
# 4                                       32.8510
#
#    Unit value 95 percent interval - upper bound  Unit value of exports  \
# 0                                      117.6797                87.4300
# 1                                      109.5255                86.4987
# 2                                       98.6185                80.2955
# 3                                      115.6161                69.7022
# 4                                       97.7396                58.4751
#
#    Urban population  Urban population (% of total population)  \
# 0      4400964.0000                                   37.1440
# 1      4725626.0000                                   38.5800
# 2      5067883.0000                                   40.0390
# 3      5427584.0000                                   41.5110
# 4      5806611.0000                                   43.0000
#
#    Urban population (%)  Urban population growth (annual %)  \
# 0               37.1000                              7.2568
# 1                   nan                              7.1176
# 2                   nan                              6.9923
# 3                   nan                              6.8571
# 4                   nan                              6.7503
#
#    Use of IMF credit (DOD, current US$)  Value-added taxes  \
# 0                                   nan                nan
# 1                                   nan                nan
# 2                                   nan                nan
# 3                                   nan                nan
# 4                                   nan                nan
#
#    Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Volume of Imports of goods  Volume of exports of goods  \
# 0                     12.9000                         nan
# 1                    -14.2570                         nan
# 2                     42.5890                         nan
# 3                    -23.3200                         nan
# 4                    -19.5740                         nan
#
#    Volume of exports of goods and services  \
# 0                                  14.6000
# 1                                   0.1860
# 2                                   8.3590
# 3                                  -8.2750
# 4                                   8.2360
#
#    Volume of imports of goods and services  \
# 0                                 -15.8000
# 1                                  -3.8860
# 2                                  21.1410
# 3                                 -19.1250
# 4                                 -26.7690
#
#    Vulnerable employment (% of total employment)  \
# 0                                            nan
# 1                                        62.6000
# 2                                            nan
# 3                                            nan
# 4                                            nan
#
#    Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            77.9570
# 2                                            77.6710
# 3                                            78.1170
# 4                                            77.5830
#
#    Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            48.1400
# 2                                            47.8000
# 3                                            48.4480
# 4                                            47.6860
#
#    Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            62.5610
# 2                                            62.2410
# 3                                            62.8110
# 4                                            62.1480
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            19.9700
# 2                                            20.2570
# 3                                            19.8400
# 4                                            20.3640
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            46.2220
# 2                                            46.5510
# 3                                            45.7510
# 4                                            46.5580
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                nan
# 1                                            33.5250
# 2                                            33.8390
# 3                                            33.2080
# 4                                            33.8880
#
#    Working poor at PPP$3.20 a day (% of total employment)  \
# 0                                                nan
# 1                                            52.7000
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Young age (0-14) dependency ratio (per 100 people ages 15-64)  \
# 0                                            95.2000
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#    Youth not in school or employment (% ages 15-24)  \
# 0                                               nan
# 1                                               nan
# 2                                               nan
# 3                                               nan
# 4                                               nan
#
#    Youth unemployment rate (female to male ratio)
# 0                                             nan
# 1                                          1.1400
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
# [5 rows x 846 columns]

# %%
# Finally Populating / Imputing Nulls!
# Step 1 is to create all the functions that will be needed to run the imputer.
# We will be extracting each country and imputing values for each country based on real values that are available for...
# ...that country

def extractor(df, country_code):
    """Extracting a country-specific dataset"""

    extract = df[df.country_code == country_code]
    extract.reset_index(inplace=True, drop = True)
    extract = extract.iloc[:,3:]
    extract.dropna(axis=1, inplace=True, how='any', thresh = 5) #removing columns that don't have atleast 5 values
    return extract

def imputer (c_extract, imputer_engine):
    """Imputing values for the extracted country"""
    
    imputed = pd.DataFrame(imputer_engine.fit_transform(c_extract))
    imputed.columns = c_extract.columns
    return imputed
    
def replacer (df, country_code, imputed):
    """Extracting country-specific dataset again to ensure that all columns are included"""
    
    extract_all_columns = df[df.country_code == country_code] 
    extract_all_columns.reset_index (inplace=True, drop = True)
    for col in imputed:
        extract_all_columns[col] = imputed[col].copy()
    return extract_all_columns

from tqdm import tqdm_notebook
def master_imputer (df, imputer_engine):
    """Master function that combines all the earlier functions to impute values for all countries and return one combined dataset"""
    
    df_imputed = pd.DataFrame()
    
    for country_code in tqdm_notebook(df.country_code.unique()):
        c_extract = extractor (df, country_code)
        imputed = imputer (c_extract, imputer_engine)
        replaced = replacer (df, country_code, imputed)
        df_imputed = pd.concat ([df_imputed, replaced], axis = 0)
    
    df_imputed.reset_index (inplace=True, drop = True)
    
    return df_imputed

# %%
# Imputing all nulls

# The model that we would be using for imputation
model = LassoCV(normalize=True, cv=3, n_alphas=100, n)

# The iterator we would be using with the relevant parameters
ii = IterativeImputer (estimator = model, tol = 0.00000000001, n_nearest_features=100)

# Calling the master_imputer function created earlier
working = master_imputer (m3, ii)

# Analyzing our results
print (working.shape)
print (working.isnull().sum())

# %%
working.describe()

# %%
# Exporting imputed file
working.to_csv('../raw_data/iterated.csv', index=False)

# Exporting original file (with same columns)
m3.to_csv ('../raw_data/wo_iterated.csv', index=False)

# %%
working.head(500)
